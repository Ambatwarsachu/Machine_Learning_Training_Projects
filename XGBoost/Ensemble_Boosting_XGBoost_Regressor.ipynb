# %%
#!pip install xgboost

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV

#metrics and models
from sklearn.metrics import r2_score, mean_squared_error
import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# Specify the engine to ensure correct format interpretation
df = pd.read_csv(r"C:\Users\Admin\Downloads\Used_Vehicles_file\vehicles_data_students.csv")

# Display the first few rows to verify it loaded correctly
df


df.shape

df.isna().sum()

list(df.columns)

drop_c = ['Unnamed: 0','id','title_status','lat','long','county']
df = df.drop(columns=drop_c,axis=1)

df.shape

df.isna().sum()

df = df.dropna()

df.shape

df.head(5)

#df = df[df['price'] != 0]

df.shape

df.sample(5)

#df = df[df['odometer'] != 0]

df.shape

df.describe()

df.drop_duplicates(inplace=True)

df.shape

df.describe()


object_type_columns = list(df.select_dtypes(include='object'))

object_type_columns

#object_type_columns_1 = list(object_type_columns) #another wayto select object datatype, you can use int and flote also

#object_type_columns_1

#Encoding catergorical columns using get dummies

df_dummies = pd.get_dummies(df[object_type_columns], drop_first=True)

df_dummies
# Out:
#        manufacturer_alfa-romeo  manufacturer_audi  manufacturer_bmw  \
# 5                        False              False             False
# 9                        False              False             False
# 30                       False              False             False
# 32                       False              False             False
# 39                       False              False             False
# ...                        ...                ...               ...
# 64008                    False              False             False
# 64010                    False              False             False
# 64014                    False              False             False
# 64015                    False              False             False
# 64031                    False              False             False
#
#        manufacturer_buick  manufacturer_cadillac  manufacturer_chevrolet  \
# 5                   False                  False                   False
# ...

# %%
df_dum=df_dummies.astype(int)
df_dum
# Out:
#        manufacturer_alfa-romeo  manufacturer_audi  manufacturer_bmw  \
# 5                            0                  0                 0
# 9                            0                  0                 0
# 30                           0                  0                 0
# 32                           0                  0                 0
# 39                           0                  0                 0
# ...                        ...                ...               ...
# 64008                        0                  0                 0
# 64010                        0                  0                 0
# 64014                        0                  0                 0
# 64015                        0                  0                 0
# 64031                        0                  0                 0
#
#        manufacturer_buick  manufacturer_cadillac  manufacturer_chevrolet  \
# 5                       0                      0                       0
# ...

# %%
df_dum.shape
# Out:
# (11323, 3439)

# %%
df= df.join(df_dum)

# %%
df.shape
# Out:
# (11323, 3453)

# %%
df.head()
# Out:
#     price    year manufacturer                  model  condition    cylinders  \
# 5       0  2006.0     chrysler                    300   like new  8 cylinders
# 9   20995  2011.0    chevrolet         silverado 1500  excellent  8 cylinders
# 30  13000  2012.0     infiniti                   g37x       good  6 cylinders
# 32  12500  2017.0        buick  encore premium sport8   like new  4 cylinders
# 39  44500  2015.0          gmc    yukon xl denali 4x4  excellent  8 cylinders
#
#    fuel  odometer transmission drive  ... state_sd state_tn state_tx state_ut  \
# 5   gas  149000.0    automatic   rwd  ...        0        0        0        0
# 9   gas   92001.0    automatic   4wd  ...        0        0        0        0
# 30  gas   49200.0    automatic   4wd  ...        0        0        0        0
# 32  gas   73057.0    automatic   4wd  ...        0        0        0        0
# 39  gas   91000.0    automatic   4wd  ...        0        0        0        0
#
# ...

# %%
df.drop(columns=object_type_columns, axis=1, inplace=True)
df
# Out:
#        price    year  odometer  manufacturer_alfa-romeo  manufacturer_audi  \
# 5          0  2006.0  149000.0                        0                  0
# 9      20995  2011.0   92001.0                        0                  0
# 30     13000  2012.0   49200.0                        0                  0
# 32     12500  2017.0   73057.0                        0                  0
# 39     44500  2015.0   91000.0                        0                  0
# ...      ...     ...       ...                      ...                ...
# 64008   2150  2002.0  151255.0                        0                  0
# 64010   3995  2003.0  161000.0                        0                  0
# 64014  15850  2008.0  151628.0                        0                  0
# 64015   8999  2010.0  125989.0                        0                  0
# 64031   8850  2015.0  114248.0                        0                  0
#
# ...

# %%
df = df[df['price']>1000]

# %%
df.shape
# Out:
# (10542, 3442)

# %%
df = df[df['price']<25000]

# %%
df.shape
# Out:
# (9009, 3442)

# %%
df = df[df['odometer']>200]

# %%
df.shape
# Out:
# (8935, 3442)

# %%
df = df[df['odometer']<100000]

# %%
df.shape
# Out:
# (2932, 3442)

# %%
#devided dataset into features and labels

x = df.drop(['price'], axis=1)
y = df['price']

# %%
#data split into train test

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=10, test_size=0.25)

# %%
#XGB model building
import xgboost as xgb

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor()

# %%
xgb_model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb_model.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6041393472531457

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score

# %%
mean_squared_error(y_test, y_pred) #MSE
# Out:
# 14381024.44023367

# %%
mean_absolute_error(y_test, y_pred) #MAE
# Out:
# 2768.69135962014

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 3792.2321184539414

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# For MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)

# For MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)

# For R-squared
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# MSE: 14381024.44023367
# MAE: 2768.69135962014
# R-squared: 0.6041393472531457

# %%
#hyperparameter tuning for increaseing the r-squared

params = {'n_estimators':[13,15],
         'criterion':['entropy','gini'],
         'max_depth':[10,15],
         'min_samples_split':[10,11],
         'min_samples_leaf':[5,6]}

# %%
grd = GridSearchCV(xgb_model,param_grid=params)
grd.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
print('best_params==>', grd.best_params_)
# Out:
# best_params==> {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 15}

# %%
xgb_regg = XGBRegressor(n_estimators=9,
                       max_samples=0.7,
                       bootstrap=True,
                       random_state=3,
                       max_depth=10,
                       min_samples_split=10,
                       min_samples_leaf=5)

# %%
xgb_regg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, bootstrap=True, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              max_samples=0.7, min_child_weight=None, min_samples_leaf=5,
#              min_samples_split=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, ...)

# %%
xgb_regg.score(x_test,y_test)
# Out:
# 0.5656471280374433

# %%
y_preddd = xgb_regg.predict(x_test)

# %%
r2_score(y_test, y_preddd)
# Out:
# 0.5656471280374433

# %%
xgb_reg = grd.best_estimator_

# %%
xgb_reg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, criterion='entropy', device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#              max_leaves=None, min_child_weight=None, min_samples_leaf=5,
#              min_samples_split=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=15, ...)

# %%
y_predd = xgb_reg.predict(x_test)

# %%
r2_score(y_test, y_predd)
# Out:
# 0.5718206900820386

# %%
#df = df.drop(object_type_columns, axis=1)
#df = pd.concat([df, df_dummies], axis=1)

df

df_dummies.shape

df=df.join(df_dummies)

df.shape

df.drop(columns=object_type_columns, axis=1, inplace=True)

df.head()
